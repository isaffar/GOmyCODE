# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import csv
import random


with open('/Users/ilhemsaffar/Desktop/GOmyCODE/iris.data.txt', 'r') as csvfile:

    lines = csv.reader(csvfile)

    for row in lines :

            print (', '.join(row))

#Next we need to split the data into a training dataset 



def loadDataset(filename, split, trainingSet=[] , testSet=[]):

    with open('/Users/ilhemsaffar/Desktop/GOmyCODE/iris.data.txt', 'r') as csvfile:

        lines = csv.reader('/Users/ilhemsaffar/Desktop/GOmyCODE/iris.data.txt')

        dataset = list(lines)

    for x in range(len(dataset)-1):

        for y in range(4):

            dataset[x][y] = float(dataset[x][y])

            if random.random() < split:

                trainingSet,testSet,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30) #split our data with test size of 20% 

                knn=KNeighborsClassifier(n_neighbors=20) #build our knn classifier
                knn.fit(trainingSet,y_train) #Training KNN classifier
                y_pred=knn.predict(testSet)  #Testing
                print('Acuuracy=',accuracy_score(y_pred,y_test))

            else:
                
                n_neighbors=30
                scores=[]
                for k in range(1,30):
                    knn=KNeighborsClassifier(n_neighbors-k)
                    knn.fit(x_train,y_train)
                    y_pred=knn.predict(x_test)
                    
                    scores.append(round(accuracy_score(y_pred,y_test),2))
                    print('Accuracy for k=',k,'is:',round(accuracy_score(y_pred,y_test),2))


                    
                    
                    
print('*****************************')
# Out:
# 5.1, 3.5, 1.4, 0.2, Iris-setosa
# 4.9, 3.0, 1.4, 0.2, Iris-setosa
# 4.7, 3.2, 1.3, 0.2, Iris-setosa
# 4.6, 3.1, 1.5, 0.2, Iris-setosa
# 5.0, 3.6, 1.4, 0.2, Iris-setosa
# 5.4, 3.9, 1.7, 0.4, Iris-setosa
# 4.6, 3.4, 1.4, 0.3, Iris-setosa
# 5.0, 3.4, 1.5, 0.2, Iris-setosa
# 4.4, 2.9, 1.4, 0.2, Iris-setosa
# 4.9, 3.1, 1.5, 0.1, Iris-setosa
# 5.4, 3.7, 1.5, 0.2, Iris-setosa
# 4.8, 3.4, 1.6, 0.2, Iris-setosa
# 4.8, 3.0, 1.4, 0.1, Iris-setosa
# 4.3, 3.0, 1.1, 0.1, Iris-setosa
# 5.8, 4.0, 1.2, 0.2, Iris-setosa
# 5.7, 4.4, 1.5, 0.4, Iris-setosa
# 5.4, 3.9, 1.3, 0.4, Iris-setosa
# 5.1, 3.5, 1.4, 0.3, Iris-setosa
# 5.7, 3.8, 1.7, 0.3, Iris-setosa
# 5.1, 3.8, 1.5, 0.3, Iris-setosa
# 5.4, 3.4, 1.7, 0.2, Iris-setosa
# 5.1, 3.7, 1.5, 0.4, Iris-setosa
# 4.6, 3.6, 1.0, 0.2, Iris-setosa
# 5.1, 3.3, 1.7, 0.5, Iris-setosa
# 4.8, 3.4, 1.9, 0.2, Iris-setosa
# 5.0, 3.0, 1.6, 0.2, Iris-setosa
# 5.0, 3.4, 1.6, 0.4, Iris-setosa
# 5.2, 3.5, 1.5, 0.2, Iris-setosa
# 5.2, 3.4, 1.4, 0.2, Iris-setosa
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import csv
import random
trainingSet=[]

testSet=[]

loadDataset('iris.data', 0.66, trainingSet=[] ,testSet=[])

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-a553b0e42b87> in <module>
#      13 testSet=[]
#      14
# ---> 15 loadDataset('iris.data', 0.66, trainingSet=[] ,testSet=[])
#      16
#      17 print ('Train: ' + repr(len(trainingSet)))
#
# <ipython-input-85-b3c068c84710> in loadDataset(filename, split, trainingSet, testSet)
#      35         for y in range(4):
#      36
# ---> 37             dataset[x][y] = float(dataset[x][y])
#      38
#      39             if random.random() < split:
#
# ValueError: could not convert string to float: '/'

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

#plt.plot(scores)
plt.plot(range(1,30))#je n'ai pas compris ce que je devrai mettre ici 
plt.xlabel('Value K for KNN')
plt.ylabel('Testing Accuracy')
plt.show()

# %%
import math

def euclideanDistance(instance1, instance2, length):
    data1 = [2, 2, 2, 'a']

    data2 = [4, 4, 4, 'b']

    distance = euclideanDistance(data1, data2, 3)

    print ('Distance: ' + repr(distance))

# %%
import math
import operator

def getNeighbors(trainingSet, testInstance, k):

    distances = []

    length = len(testInstance)-1

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet[x], length)

        distances.append((trainingSet[x], dist))

        distances.sort(key=operator.itemgetter(1))

        neighbors = []

    for x in range(k):

        neighbors.append(distances[x][0])

        return neighbors



trainSet = [[2, 2, 2, 'a'], [4, 4, 4, 'b']]

testInstance = [5, 5, 5]

k = 1

neighbors = getNeighbors(trainSet, testInstance, 1)

neighbors
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-4-3321fe48ad33> in <module>
#      32 k = 1
#      33
# ---> 34 neighbors = getNeighbors(trainSet, testInstance, 1)
#      35
#      36 neighbors
#
# <ipython-input-4-3321fe48ad33> in getNeighbors(trainingSet, testInstance, k)
#      10     for x in range(len(trainingSet)):
#      11
# ---> 12         dist = euclideanDistance(testInstance, trainingSet[x], length)
#      13
#      14         distances.append((trainingSet[x], dist))
#
# <ipython-input-1-112ef02ba7da> in euclideanDistance(instance1, instance2, length)
#       8     data2 = [4, 4, 4, 'b']
#       9
# ---> 10     distance = euclideanDistance(data1, data2, 3)
#      11
#      12     print ('Distance: ' + repr(distance))
#
# ... last 1 frames repeated, from the frame below ...
#
# ...

# %%
import operator

def getResponse(neighbors):

    classVotes = {}

    for x in range(len(neighbors)):

        response = neighbors[x][3] #complete with appropriate number

        if response in classVotes:

            

            sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)

            return sortedVotes[0][0]

#We can test out this function with some test neighbors, as follows:

neighbors = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

response = getResponse(neighbors)

print(response)
# Out:
# None

# %%
import operator
def getAccuracy(testSet, predictions):
    
    return (0.2/float(len(testSet))) * 100.0 #correct je ne sais pas elle vient d'où donc j'ai remplacé pr 0.2



testSet = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

predictions = ['a', 'a', 'a']

accuracy = getAccuracy(testSet, predictions)

print(accuracy)
# Out:
# 6.666666666666667
